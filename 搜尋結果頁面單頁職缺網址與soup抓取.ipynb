# %%
import requests
from bs4 import BeautifulSoup as bs
import time

# %%
search_url = input('請輸入搜尋頁面網址 ')

# %%
search_url = \
'https://www.104.com.tw/jobs/search/?ro=0&keyword=flask&area=6001002000%2C6001001000&order=1&asc=0&page=5&mode=s&jobsource=2018indexpoc'

# %%
head = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/60.0.3112.90 Safari/537.36',
        'Accept-Language':'zh-TW,zh;q=0.8,en-US;q=0.6,en;q=0.4'} 
resp = requests.get(search_url, headers = head)
soup_search = bs(resp.text)
soup_search
# Out:
# <!DOCTYPE html>
# <html lang="zh-hant">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>關鍵字(flask)、新北市、台北市 - 104人力銀行工作列表</title>
# <meta content="104提供最多工作機會，有效率的找到好工作，並提供專業求職服務、履歷健診、職務百科、升學就業地圖，不只找工作，為你找方向" name="description"/>
# <meta content="全職工作、兼職、打工" name="keywords"/>
# <meta content="關鍵字(flask)、新北市、台北市 - 104人力銀行工作列表" property="og:title"/>
# <meta content="//static.104.com.tw/logo/104logo_200x200_fbogW2.png" property="og:image"/>
# <meta content="//static.104.com.tw/logo/104logo_200x200_fbogM2.png" property="og:image"/>
# <meta content="104人力銀行" property="og:site_name"/>
# <meta content="104提供最多工作機會，有效率的找到好工作，並提供專業求職服務、履歷健診、職務百科、升學就業地圖，不只找工作，為你找方向" property="og:description"/>
# <meta content="index,follow,archive" name="robots"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;keyword=flask&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;mode=s&amp;page=5" rel="canonical"/>
# <link href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;keyword=flask&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;mode=s&amp;page=4" rel="prev"/>
# <link href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;keyword=flask&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;mode=s&amp;page=6" rel="next"/>
# <link href="//m.104.com.tw/search/joblist/?ro=0&amp;kwop=7&amp;keyword=flask&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;mode=s" media="only screen and (max-width: 640px)" rel="alternate"/>
# <link href="//static.104.com.tw/104main/jb/css/common.css?v=190110" rel="stylesheet" type="text/css"/>
# <link href="//www.104.com.tw/jobs/search/static/poc/css/vendor.css?v=190110" rel="stylesheet" type="text/css"/>
# <link href="//www.104.com.tw/jobs/search/static/poc/css/main.min.css?v=190110" rel="stylesheet" type="text/css"/>
# <link href="//www.104.com.tw/jobs/search/static/poc/css/pages.min.css?v=190110" rel="stylesheet" type="text/css"/>
# <link href="//static.104.com.tw/104main/pda/css/category_org.css?v=190110" rel="stylesheet" type="text/css"/>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#     new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#     j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#     'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','dataLayer','GTM-P379T3');</script>
# <script type="text/javascript">
#     _atrk_opts = { atrk_acct:"lRlHh1awVK00wf", domain:"104.com.tw",dynamic: true};
#     (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://certify-js.alexametrics.com/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#     </script>
# <noscript><img alt="" height="1" src="https://certify.alexametrics.com/atrk.gif?account=lRlHh1awVK00wf" style="display:none" width="1"/></noscript>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonArea.js?v=190110"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonJobCat.js?v=190110"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonJobCatH.js?v=190110"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonIndust.js?v=190110"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonMajor.js?v=190110"></script>
# <script async="" src="//www.104.com.tw/public/function01/utf8/jsonAreaWork.js?v=190110"></script>
# </head>
# <body class="job-list-body" id="job-jobList">
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P379T3" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <header class="l-header header">
# <div id="globalbar">
# <div id="bar_m104">
# <div id="global_bk"></div>
# </div>
# </div>
# <div class="l-container">
# <div class="b-logo b-float-left">
# <a href="//www.104.com.tw">
# <img alt="104人力銀行" src="//static.104.com.tw/logo/104logo_o_180x26.svg"/>
# </a>
# </div>
# <div class="b-banner--dimond b-float-right" id="js-aidma-board-2">
# </div>
# </div>
# </header>
# <main>
# <div class="tool-area b-fixed-right">
# <ul class="side-tools poc-tools">
# <li class="intro" id="intro">
# <a href="javascript:void(0)">
# <svg class="icon-intro b-icon--weak-gray b-icon--w24">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-intro"></use>
# </svg>
# <span>新版介紹</span>
# </a>
# </li>
# </ul>
# <ul class="side-tools">
# <li class="gtm-fixed-save">
# <a href="//pda.104.com.tw/forward.cfm?fun_code=16wkfuejxt" target="blank">
# <svg class="icon-star b-icon--weak-gray b-icon--w24">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-star"></use>
# </svg>
# <span>儲存清單</span>
# </a>
# </li>
# <li class="gtm-fixed-feedback">
# <a href="//www.104survey.com/104Survey/survey/action/questionFillin/QuestionPresentAction.jsf?surveyId=011999990116399FFFFF6666000F8EEF71105559FEE90000RJSS&amp;pointMsg=false" target="_blank">
# <svg class="icon-reply b-icon--weak-gray b-icon--w24">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-reply"></use>
# </svg>
# <span>我要回饋</span>
# </a>
# </li>
# <li class="go-top gtm-fixed-gotop" id="go-top">
# <a class="b-icon b-hide" href="#">
# <svg class="icon-go-top b-icon--weak-gray b-icon--w24">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-go-top"></use>
# </svg>
# <span>回到頂部</span>
# </a>
# </li>
# </ul>
# </div>
# <div class="search-wrapper" id="search-wrapper">
# <div class="main-search">
# <form autocomplete="off" class="l-container main-search__form" id="js-search-form">
# <div class="b-fake-input">
# <div class="b-search-block--l">
# <input data-temp="" id="keyword" maxlength="50" placeholder="關鍵字(例：職稱、公司名、技能專長...)" type="text"/>
# <svg class="icon-clear b-icon--weak-gray b-icon--w16" xmlns="http://www.w3.org/2000/svg">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear">
# </use>
# </svg>
# </div>
# <span class="b-divide"></span>
# <div class="b-search-block--m">
# <input data-temp="" id="area-cat" placeholder="地區" readonly="" type="text"/>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </div>
# <span class="b-divide"></span>
# <div class="b-search-block--m">
# <input data-temp="" id="job-cat" placeholder="職務類別" readonly="" type="text"/>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </div>
# </div>
# <button class="b-btn b-btn--primary is-large gtm-main-search" type="submit">
#                     搜尋
#                 </button>
# <div class="main-search__auxiliary" id="search-relative">
# <label>
# <input class="b-checkbox" id="only-title" type="checkbox"/>
#                         只搜尋職務名稱
#                     </label>
# <p class="js-related-keyword js-related-keyword--related related-keyword">
#                             相關搜尋：
#                             <span><a class="js-startby" href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;page=5&amp;mode=s&amp;startby=4&amp;jobsource=n104bank1">可年後上班</a></span>
# <span>
# <a class="b-link--gray" href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;page=5&amp;mode=s&amp;keyword=Django&amp;jobsource=keyword2Keyword">
#                                         Django
#                                     </a>
# </span>
# <span>
# <a class="b-link--gray" href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;page=5&amp;mode=s&amp;keyword=Node.js&amp;jobsource=keyword2Keyword">
#                                         Node.js
#                                     </a>
# </span>
# <span>
# <a class="b-link--gray" href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;page=5&amp;mode=s&amp;keyword=Git&amp;jobsource=keyword2Keyword">
#                                         Git
#                                     </a>
# </span>
# <span>
# <a class="b-link--gray" href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;page=5&amp;mode=s&amp;keyword=NoSQL&amp;jobsource=keyword2Keyword">
#                                         NoSQL
#                                     </a>
# </span>
# <span>
# <a class="b-link--gray" href="//www.104.com.tw/jobs/search/?ro=0&amp;kwop=7&amp;area=6001002000%2C6001001000&amp;order=1&amp;asc=0&amp;page=5&amp;mode=s&amp;keyword=Python&amp;jobsource=keyword2Keyword">
#                                         Python
#                                     </a>
# </span>
# </p>
# <label>
# <input class="b-checkbox gtm-highend-switch" id="job-type" type="checkbox"/>切換高階職類
#                     </label>
# </div>
# </form>
# </div>
# <div class="filter-search is-shadow" id="filter-search">
# <div class="l-container">
# <ul class="js-filter-tab b-tabs" id="js-filter-tab">
# <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="0">
# <span class="b-tabs__txt js-tab-title" data-title="更新日期">
#                             更新日期
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li>
# <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="1">
# <span class="b-tabs__txt js-tab-title" data-title="休假制度">
#                             休假制度
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li>
# <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="2">
# <span class="b-tabs__txt js-tab-title" data-title="薪資待遇">
#                             薪資待遇
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li>
# <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="3">
# <span class="b-tabs__txt js-tab-title" data-title="經歷要求">
#                             經歷要求
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li>
# <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="4">
# <span class="b-tabs__txt js-tab-title" data-title="公司相關">
#                             公司相關
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li>
# <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="5">
# <span class="b-tabs__txt js-tab-title" data-title="更多條件">
#                             更多條件
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li>
# <li class="b-tabs__item js-arrow-toggle js-tab-content" data-value="6">
# <span class="b-tabs__txt js-tab-title" data-title="排除條件">
#                             排除條件
#                         </span>
# <svg class="b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-arrow-down">
# </use>
# </svg>
# </li>
# </ul>
# <ul class="b-tabs__right-side">
# <li class="b-tabs__item gtm-sub-clear" id="js-filter-clear">
# <svg class="b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-empty">
# </use>
# </svg>
# <span class="text-label" data-title="清空條件">
#                             清空條件
#                         </span>
# </li>
# <div class="b-divide"></div>
# <li class="b-tabs__item job-match-btn gtm-sub-subscription" data-popup="saveCondition" id="search-conditon" title="檢視或訂閱條件">
# <svg class="b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-ring">
# </use>
# </svg>
# <span class="text-label">檢視或訂閱條件</span>
# </li>
# </ul>
# <div>
# <img alt="104人力銀行 - 新版介紹" class="intro-step1 intro-layer" src="//www.104.com.tw/jobs/search/static/poc/img/intro/intro-1.jpg" srcset="//www.104.com.tw/jobs/search/static/poc/img/intro/intro-1@2x.jpg 2x, //www.104.com.tw/jobs/search/static/poc/img/intro/intro-1@3x.jpg 3x"/>
# <img alt="104人力銀行 - 新版介紹" class="intro-step2 intro-layer" src="//www.104.com.tw/jobs/search/static/poc/img/intro/intro-2.jpg" srcset="//www.104.com.tw/jobs/search/static/poc/img/intro/intro-2@2x.jpg 2x, //www.104.com.tw/jobs/search/static/poc/img/intro/intro-2@3x.jpg 3x"/>
# <img alt="104人力銀行 - 新版介紹" class="intro-step3 intro-layer" src="//www.104.com.tw/jobs/search/static/poc/img/intro/intro-3.jpg" srcset="//www.104.com.tw/jobs/search/static/poc/img/intro/intro-3@2x.jpg 2x, //www.104.com.tw/jobs/search/static/poc/img/intro/intro-3@3x.jpg 3x"/>
# </div>
# </div>
# <div class="l-content b-tabs-content has-background is-shadow b-hide js-sub-filter" id="js-sub-filter">
# <div class="l-container sub-search">
# <div class="js-filter-tab-content js-filter-select-list b-hide" data-filter-type="updateTime" data-select-type="1"></div>
# <div class="js-filter-tab-content js-filter-select-list b-hide" data-filter-type="workingDays" data-select-type="1"></div>
# <div class="js-filter-tab-content b-hide" data-select-type="1" id="js-salary">
# <dl class="labels-field">
# <dt>
# <span class="title">薪資條件</span>
# </dt>
# <dd>
# <span class="js-salary-list">
# <label>
# <input type="checkbox" value="99"/>
# <span>有寫薪資</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# <label>
# <input type="checkbox" value="160"/>
# <span>時薪160up</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# <label>
# <input type="checkbox" value="30000"/>
# <span>月薪3萬up</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# <label>
# <input type="checkbox" value="40000"/>
# <span>月薪4萬up</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# <label>
# <input type="checkbox" value="50000"/>
# <span>月薪5萬up</span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# </span>
# </dd>
# </dl>
# <dl class="labels-field select-field" id="js-salary-custom">
# <dt>
# <span class="title">自訂條件</span>
# </dt>
# <dd>
# <span class="labels">
# <label class="js-salary-range b-hide">
# <input type="checkbox"/>
# <span></span>
# <svg class="icon-clear b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear"></use>
# </svg>
# </label>
# </span>
# <div class="salary-custom js-salary-custom select-category">
# <div class="salary-input js-salary-input">
# <div class="input-group">
# <select class="b-clear-border cus-select js-salary-type">
# <option value="H">時薪</option>
# <option value="D">日薪</option>
# <option selected="selected" value="M">月薪</option>
# <option value="Y">年薪</option>
# </select>
# <div class="b-divide"></div>
# <input autocomplete="off" class="salary-min b-clear-border js-salary-min" maxlength="7" placeholder="如28000" type="number"/>
# </div>
# <span class="b-dash"></span>
# <input autocomplete="off" class="js-salary-max salary-max" maxlength="7" placeholder="可不填" type="number"/>
# <button class="b-btn b-btn--default js-salary-send" disabled="">
#                                             送出
#                                         </button>
# </div>
# </div>
# </dd>
# </dl>
# <dl class="labels-field" id="salary-result">
# <dt>
# <span class="title">查詢結果</span>
# </dt>
# <dd class="salary-result-all">
# <span>
# <label class="freeze">
# <input checked="" class="b-checkbox" type="checkbox" value="1"/>
# <span>所有工作</span>
# </label>
# </span>
# </dd>
# <dd class="js-filter-select-checkbox-list" data-filter-type="salaryStrict" data-select-type="1"></dd>
# <dd class="js-filter-select-checkbox-list" data-filter-type="salaryNeg" data-select-type="1"></dd>
# </dl>
# </div>
# <div class="js-filter-tab-content js-filter-select-list b-hide" data-filter-type="experience" data-select-type="2"></div>
# <div class="js-filter-tab-content b-hide">
# <dl class="labels-field select-field js-middle-select-list">
# <dt>
# <span class="title">公司產業</span>
# </dt>
# <dd>
# <span class="labels js-filter-select-category" data-category-desc="選擇其他產業" data-filter-type="industry"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">科技園區</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="techArea" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field select-field js-middle-select-list">
# <dt>
# <span class="title">工業區</span>
# </dt>
# <dd>
# <span class="labels js-filter-select-category" data-category-desc="請選擇工業區" data-filter-type="areaWork"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">福利制度</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="welfare" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">公司類型</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="custType" data-select-type="1"></dd>
# </dl>
# </div>
# <div class="js-filter-tab-content b-hide">
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">上班時段</span>
# </dt>
# <dd>
# <span class="js-filter-select-list" data-filter-type="workingHours" data-select-type="2"></span>
# <span class="b-divide"></span>
# <span class="js-filter-select-list" data-filter-type="shiftwork" data-select-type="1"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">工讀性質</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="partTime" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">學歷要求</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="education" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">外語要求</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="language" data-select-type="2"></dd>
# </dl>
# <dl class="labels-field select-field js-middle-select-list">
# <dt>
# <span class="title">科系要求</span>
# </dt>
# <dd>
# <span class="labels js-filter-select-category" data-category-desc="選擇科系" data-filter-type="major" id="js-major"></span>
# </dd>
# </dl>
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">身份類型</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="roleStatus" data-select-type="2"></dd>
# <dd class="js-filter-select-list" data-filter-type="isManager" data-select-type="1"></dd>
# <dd class="js-filter-select-list" data-filter-type="startby" data-select-type="1"></dd>
# </dl>
# </div>
# <div class="js-filter-tab-content b-hide">
# <dl class="labels-field js-middle-select-list">
# <dt>
# <span class="title">排除派遣</span>
# </dt>
# <dd class="js-filter-select-list" data-filter-type="excludeTemp" data-select-type="1"></dd>
# </dl>
# <dl class="labels-field select-field">
# <dt>
# <span class="title">排除產業</span>
# </dt>
# <dd>
# <span class="labels js-middle-select-list" id="js-exclude-industry"></span>
# </dd>
# </dl>
# <dl class="labels-field select-field">
# <dt>
# <span class="title">排除關鍵字</span>
# </dt>
# <dd id="js-exclude-job">
# <span class="labels js-middle-select-list" id="js-exclude-job-field"></span>
# <div class="text-input">
# <input maxlength="30" placeholder="請輸入欲排除的關鍵字" type="text"/>
# <button class="b-btn b-btn--default" disabled="">送出</button>
# </div>
# </dd>
# </dl>
# <dl class="labels-field select-field">
# <dt>
# <span class="title">排除公司</span>
# </dt>
# <dd id="js-exclude-company">
# <span class="labels js-middle-select-list" id="js-exclude-company-field"></span>
# <div class="text-input">
# <input placeholder="請輸入公司名稱" type="text"/>
# <button class="b-btn b-btn--default" disabled="">送出</button>
# </div>
# </dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="l-content--2col b-clearfix" id="main-content">
# <div class="l-content--2col--main l-container jobs-content">
# <div class="job-tab b-clearfix" id="js-job-header">
# <div class="b-float-right">
# <label class="b-select">
# <select class="page-select js-paging-select gtm-paging-top"></select>
# </label>
# <label class="b-select">
# <select id="js-sort">
# <option value="1-0">相關性排序</option>
# <option value="2-0">日期排序</option>
# <option value="4-0">學歷 高→低</option>
# <option value="4-1">學歷 低→高</option>
# <option value="3-0">經歷 多→少</option>
# <option value="3-1">經歷 少→多</option>
# <option value="7-0">應徵人數 多→少</option>
# <option value="7-1">應徵人數 少→多</option>
# </select>
# </label>
# <ul class="job-switch-mode">
# <li class="js-mode-summary">
# <a href="javascript:;" title="摘要">
# <svg class="b-icon--w18 b-pointer-events">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-mode-s" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </li>
# <li class="js-mode-list">
# <a href="javascript:;" title="列表">
# <svg class="b-icon--w18 b-pointer-events">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-mode-l" xmlns:xlink="http://www.w3.org/1999/xlink"></use>
# </svg>
# </a>
# </li>
# </ul>
# </div>
# <div class="b-float-left">
# <ul class="b-nav-tabs job-type" id="js-job-tab">
# <li data-value="0">全部<span class="js-txt"></span></li>
# <li data-value="1">全職<span class="js-txt"></span></li>
# <li data-value="2">兼職<span class="js-txt"></span></li>
# <li data-value="3">高階<span class="js-txt"></span></li>
# <li class="b-drowdown" data-value="4">
# <button class="b-btn b-btn--dropdown" id="js-job-more">其他</button>
# <ul class="b-drowdown__menu b-hide">
# <li data-value="4">派遣<span class="js-txt"></span></li>
# <li data-value="5">接案<span class="js-txt"></span></li>
# <li data-value="6">家教<span class="js-txt"></span></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# <div class="b-block b-clear-border b-clearfix job-list" id="js-job-list">
# <div class="b-block--top-bord job-list-item b-block--load b-clearfix js-loading-refresh b-hide">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"></span>
# </h2>
# <ul class="b-list-inline b-clearfix job-list-item__company">
# <li class="b-list-inline__ad-icon"></li>
# <li></li>
# </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content job-list-item__summary">
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <p class="job-list-item__info b-content"></p>
# <p class="job-list-item__info b-content"></p>
# <div class="job-list-tag b-content">
# <span class="b-tag--default"></span>
# </div>
# </div>
# <div class="b-block__right b-pos-relative">
# <div class="rule-out b-hide">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn js-exclude">icon</button>
# <ul class="b-drowdown__menu b-drowdown__right">
# <li>不想看到這個公司</li>
# <li>不想看到這個產業</li>
# </ul>
# </div>
# <button class="b-btn b-btn--active" disabled=""></button>
# <button class="b-btn b-btn--default" disabled=""></button>
# <button class="b-btn b-btn--link" disabled=""></button>
# </div>
# </div>
# <div class="b-block--top-bord job-list-item b-block--load b-clearfix js-loading-refresh b-hide">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"></span>
# </h2>
# <ul class="b-list-inline b-clearfix job-list-item__company">
# <li class="b-list-inline__ad-icon"></li>
# <li></li>
# </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content job-list-item__summary">
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <p class="job-list-item__info b-content"></p>
# <p class="job-list-item__info b-content"></p>
# <div class="job-list-tag b-content">
# <span class="b-tag--default"></span>
# </div>
# </div>
# <div class="b-block__right b-pos-relative">
# <div class="rule-out b-hide">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn js-exclude">icon</button>
# <ul class="b-drowdown__menu b-drowdown__right">
# <li>不想看到這個公司</li>
# <li>不想看到這個產業</li>
# </ul>
# </div>
# <button class="b-btn b-btn--active" disabled=""></button>
# <button class="b-btn b-btn--default" disabled=""></button>
# <button class="b-btn b-btn--link" disabled=""></button>
# </div>
# </div>
# <div class="b-block--top-bord job-list-item b-block--load b-clearfix js-loading-refresh b-hide">
# <div class="b-block__left">
# <h2 class="b-tit">
# <span class="b-tit__date"></span>
# </h2>
# <ul class="b-list-inline b-clearfix job-list-item__company">
# <li class="b-list-inline__ad-icon"></li>
# <li></li>
# </ul>
# <ul class="b-list-inline b-clearfix job-list-intro b-content job-list-item__summary">
# <li></li>
# <li></li>
# <li></li>
# <li></li>
# </ul>
# <p class="job-list-item__info b-content"></p>
# <p class="job-list-item__info b-content"></p>
# <div class="job-list-tag">
# <span class="b-tag--default"></span>
# </div>
# </div>
# <div class="b-block__right b-pos-relative">
# <div class="rule-out b-hide">
# <button class="b-btn b-btn--icon b-drowdown rule-out__btn js-exclude">icon</button>
# <ul class="b-drowdown__menu b-drowdown__right">
# <li>不想看到這個公司</li>
# <li>不想看到這個產業</li>
# </ul>
# </div>
# <button class="b-btn b-btn--active" disabled=""></button>
# <button class="b-btn b-btn--default" disabled=""></button>
# <button class="b-btn b-btn--link" disabled=""></button>
# </div>
# </div>
# <div id="js-job-content">
# <div class="job-list-item b-block--nodata b-pos-relative">
# <div>
# <svg class="b-icon--weak-gray b-icon-nodata--login">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-data--none"></use>
# </svg>
# </div>
# <div class="b-center b-txt--center">
# <p class="b-tit">呃拍謝，搜尋結果好像很少</p>
# <p>搜尋條件無符合工作機會，建議放寬條件重新查詢</p>
# </div>
# </div>
# </div>
# <div class="b-block b-txt--center" id="js-loading-next-page">
# <icon class="fa fa-spinner fa-pulse"></icon>
#                     載入第<span>1</span>頁
#                 </div>
# </div>
# </div>
# <aside class="l-content--2col--sub">
# <section>
# <article class="ad-article adima-section" id="js-aidma-board-3">
# <h3>強力放送</h3>
# </article>
# <article class="ad-img" id="js-aidma-board-1">
# </article>
# </section>
# </aside>
# </div>
# </main>
# <footer id="ft-thin">
# <div class="bar">
# <button class="button text cs" type="button"><span class="jbi-s18-tel"></span>104 客服</button>
# <div class="dialog-layer arrow-bottom" id="custom-service">
# <div class="dl-arrow">
# <div class="dl-arwout"></div>
# <div class="dl-arwin"></div>
# </div>
# <button class="button text dl-close" title="關閉"><span class="jbi-s15-close-small"></span></button>
# <div class="dl-content">
# <div class="char user">
# <div class="identify"><span class="jbi-s18-user"></span>我是求職者</div>
# <div class="contact">
# <dl>
# <dt>求職服務專線</dt>
# <dd>02-2912-6104 轉2</dd>
# <dd>02-7703-3104 轉2</dd>
# </dl>
# <div class="mail"><a href="//www.104.com.tw/question_admin/reaction.cfm" target="_blank"><span class="jbi-s18-mail"></span>意見回饋</a></div>
# <div class="safety"><a href="javascript:void(0)" onclick="window.open('//www.104.com.tw/public/pda/pop_safety.htm','','scrollbars=yes,width=500,height=480')"><span class="jbi-s15-care"></span>職場安全諮詢專線</a></div>
# </div>
# </div>
# <div class="char company">
# <div class="identify"><span class="jbi-s18-building"></span>我是求才廠商</div>
# <div class="contact">
# <dl>
# <dt>廠商求才專線</dt>
# <dd>
# <ul>
# <li>台北 02-2912-6104</li>
# <li>        02-7703-3104</li>
# <li>台中 04-3700-6104</li>
# <li>上海 86-21-50277104 轉1</li>
# </ul>
# </dd>
# </dl>
# <div class="mail"><a href="//www.104.com.tw/redirect/vip_message.htm" target="_blank"><span class="jbi-s18-mail"></span>意見回饋</a></div>
# </div>
# </div>
# <div class="clearfix"></div>
# <div class="time">服務時間：週一至週五9:00~19:00</div>
# </div>
# </div>
# <a class="tel" href="javascript:void(0)" onclick="window.open('//www.104.com.tw/public/pda/pop_safety.htm','','scrollbars=yes,width=500,height=480')"><span class="jbi-s15-care"></span>職場安全諮詢專線</a>
# <div class="clearfix"></div>
# </div>
# <div class="copyright">
#         一零四資訊科技股份有限公司　版權所有 ©2019　建議瀏覽器Chrome / IE11.0以上
#     </div>
# </footer>
# <script type="text/javascript">
#   (function (window) {
#     if (window.location !== window.top.location) {
#       window.top.location = encodeURI(window.location);
#     }
#   })(this);
# </script>
# <div id="divorg"></div>
# <div class="b-popup-overlay b-hide"></div>
# <div class="b-popup b-popup--m mate-box b-hide" id="saveCondition">
# <h2 class="b-popup__title">檢視或訂閱條件</h2>
# <div class="b-popup__content">
# <div class="b-txt--center" id="not-login-mate">請登入my104會員中心</div>
# <div class="b-txt--center login-mate" id="login-mate">
# <p class="subscription-text">將本次搜尋條件儲存為配對工作，即可收到最新的工作通知</p>
# <p class="subscription-condition">
#                 您的條件：
#                 <span class="js-filter-desc"></span>
# </p>
# <div class="subscription-form">
# <div>
# <p class="b-txt--center js-notice-text subscription-notice"></p>
# <input class="js-under-condition is-large" type="text" value=""/>
# <div class="js-over-condition is-large b-inline-block">
# <select class="cus-select"></select>
# </div>
# <a class="gtm-subscription-edit" href="//pda.104.com.tw/my104/mate/index" target="_blank">
#                         編輯配對條件
#                     </a>
# <div class="b-error-msg js-msg"></div>
# </div>
# <div class="check-mail">
# <label class="js-mate-emailbox subscription-mail">
# <input class=" b-checkbox" type="checkbox"/>配對信同步寄至：
#                         <span class="js-mate-mail"></span>
# </label>
# <a class="js-edit-mail" href="javascript:void(0)" target="_blank">
#                         修改接收信箱
#                     </a>
# </div>
# </div>
# </div>
# </div>
# <div class="b-popup__footer">
# <button class="b-btn b-btn--normal is-large js-popup-close gtm-subscription-cancel">
#             取消
#         </button>
# <button class="b-btn b-btn--primary is-large js-on-ok gtm-subscription-send">
#             確認
#         </button>
# </div>
# <div class="b-popup__msg b-hide js-msg">
# <p>請選擇要取代的配對條件。</p>
# </div>
# <div class="b-popup__close js-popup-close">
# <svg class="icon-clear b-icon--weak-gray b-icon--w16">
# <use xlink:href="//www.104.com.tw/jobs/search/static/poc/img/sprite.svg#icon-clear"></use>
# </svg>
# </div>
# </div>
# <div class="b-popup b-hide notice js-notice">
# <h2 class="b-popup__title b-txt--left">有新工作立即通知？</h2>
# <div class="b-popup__content">
#         將本次搜尋條件儲存成工作配對，即可在「My104、手機App、E-mail」收到最新的工作通知。
#     </div>
# <div class="b-popup__footer b-txt--right b-clear-margin">
# <button class="b-btn b-btn--text" id="noticeOnClose">我知道了</button>
# <button class="b-btn b-btn--normal gtm-notice-subscription" id="noticeOnOk">訂閱</button>
# </div>
# </div>
# <div class="b-block--loading" id="js-action-overlay">
# <div class="b-center">
# <div class="loader-inner ball-spin-fade-loader"></div>
# <div>資料處理中…</div>
# </div>
# </div>
# <form id="js-action-form" method="post" name="actionForm" target="_blank"></form>
# <script src="//static.104.com.tw/104main/libs/mit/jquery/3.3.1/jquery.min.js"></script>
# <script src="//www.104.com.tw/jobs/search/static/poc/js/vendor.js?v=190110"></script>
# <script>
#
#     var defPublicPath = "//www.104.com.tw",
#         defCasePath   = "//case.104.com.tw",
#         defTutorPath  = "//tutor.104.com.tw",
#         defLearnPath  = "//learn.104.com.tw",
#         defAidma      = {"wid":"2","cid":"6","bid":["588","502","128","132"]};
#     var defAssetsPath = "//www.104.com.tw/jobs/search/static/poc";
#     var initFilter = {"query":{"ro":0,"jobcat":"","isnew":"","kwop":7,"keyword":"flask","excludeKeyword":"","area":"6001002000,6001001000","indcat":"","expcate":"","edu":"","order":1,"asc":0,"zone":"","dep":"","dis_role":"","lang":"","sr":"","sctp":"","scmin":"","scmax":"","scstrict":"","scneg":"","excludeJobKeyword":"","excludeCompanyKeyword":"","excludeCompanyByCustno":"","excludeIndustryCat":"","s9":"","s5":"","wktm":"","startby":"","rostatus":"","page":5,"wf":"","jobexp":"","wt":"","mode":"s","jobsource":"2018indexpoc","c":"","dist":"","lat":"","lon":"","indArea":"","newZone":"","searchTempExclude":"","manage":""},"filterDesc":{"jobcat":[],"indcat":[],"area":[{"no":6001002000,"des":"\u65b0\u5317\u5e02"},{"no":6001001000,"des":"\u53f0\u5317\u5e02"}],"dep":[],"excludeIndustryCat":[],"excludeCompanyByCustno":[],"recommendIndcat":[{"no":"1001000000","des":"\u96fb\u5b50\u8cc7\u8a0a \uff0f\u8edf\u9ad4\uff0f\u534a\u5c0e\u9ad4\u76f8\u95dc\u696d"},{"no":"1002000000","des":"\u4e00\u822c\u88fd\u9020\u696d"},{"no":"1003000000","des":"\u6279\u767c\uff0f\u96f6\u552e\uff0f\u50b3\u76f4\u92b7\u696d"},{"no":"1001001000","des":"\u8edf\u9ad4\u53ca\u7db2\u8def\u76f8\u95dc\u696d"},{"no":"1007000000","des":"\u65c5\u904a\uff0f\u4f11\u9592\uff0f\u904b\u52d5\u696d"}],"indArea":[]},"queryDesc":{"ro":"\u5168\u90e8\u5de5\u4f5c","keyword":"\u95dc\u9375\u5b57(flask)","area":"\u65b0\u5317\u5e02\u3001\u53f0\u5317\u5e02"},"count":["47","47","0","0","0","0","0"],"pageNo":5,"totalPage":0,"totalCount":47};
#     var staticPath = "//static.104.com.tw";
#
#     $('.loader-inner').loaders();
#
# </script>
# <script src="//www.104.com.tw/public/function01/menu/js/e104menu2011.js?v=190110"></script>
# <script async="" src="//aidma.104.com.tw/js/e104aidma.php?wid=2&amp;cid=6"></script>
# <script src="//static.104.com.tw/104i/js/api/log/e104.log.latest.js?v=190110"></script>
# <script src="//static.104.com.tw/bubble/js/mainjs.js?v=190110"></script>
# <script src="//www.104.com.tw/jobs/search/static/poc/js/common.min.js?v=190110"></script>
# <script src="//www.104.com.tw/jobs/search/static/poc/js/joblist.bundle.min.js?v=190110"></script>
# </body>
# </html>

# %%
jobs=soup_search.select('.js-job-link')

# %%
len(jobs)
# Out:
# 0

# %%
page_urls=[]
for job in jobs:
    print('https:'+job['href'])
    page_urls.append('https:'+job['href'])

# %%
page_urls
# Out:
# ['https://www.104.com.tw/job/?jobno=4od9t&jobsource=hotjob_chr',
#  'https://www.104.com.tw/job/?jobno=6iwdk&jobsource=hotjob_chr',
#  'https://www.104.com.tw/job/?jobno=6j17u&jobsource=hotjob_chr',
#  'https://www.104.com.tw/job/?jobno=67rzs&jobsource=hotjob_chr',
#  'https://www.104.com.tw/job/?jobno=6eeit&jobsource=hotjob_chr',
#  'https://www.104.com.tw/job/?jobno=4gqmv&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=4i33g&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=61u9x&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=4w9tn&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=6iw7s&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=6apze&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=4klhn&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=5jvlh&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=66ghm&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=4qvwg&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=5cwmw&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=6hpud&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=6eulr&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=417q4&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=5v7qa&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=422lq&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=4u6wr&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=591v0&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=5lwzh&jobsource=2018indexpoc',
#  'https://www.104.com.tw/job/?jobno=6isp6&jobsource=2018indexpoc']

# %% [markdown]
# ### 工具箱函式

# %%
def from_jobsoup_load_desc(jobsoup):
    job={}
    job['職位名稱']=jobsoup.find_all('meta')[4]['content'].rstrip(' - 104人力銀行')
    job['工作地點']=jobsoup.find('dd','addr').text.strip().split()[0]
    job['工作內容']=jobsoup.find('p').text.replace('\r','')
    job['擅長工具']=jobsoup.select('.info')[1].find_all('dd')[-3].text
    job['工作技能']=jobsoup.select('.info')[1].find_all('dd')[-2].text
    job['其它條件']=jobsoup.select('.info')[1].find_all('dd')[-1].text.replace('\r','')
    for k,v in job.items():
        if v in ('不拘','未填寫'):
            job[k]=''
    return job

# %%
tuple(enumerate([3,3]))
# Out:
# ((0, 3), (1, 3))

# %%
def from_joburl_to_jobsoup(joburl):
